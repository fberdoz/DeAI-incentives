# %% [markdown]
# # Federated Learning Contribution Measure Model (Income dataset)
# This notebook implements a simple contribution model based on the notebook exemple of the DeAI repository. More precisely, it emulates a framework where `NUM_CLIENTS` clients are learning adult income prediction and average their models.

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from sklearn.preprocessing import LabelEncoder

import time

# Custom functions
from helpers import *

# Visualization
from matplotlib import pyplot as plt
from visualization import *
plt.rc('legend', fontsize='small')
plt.style.use('bmh')

# Reproductibiity
SEED = 123
torch.manual_seed(SEED)
np.random.seed(SEED)

# Console priniting option
np.set_printoptions(precision=3, suppress=False)

# %% [markdown]
# ### Model
# `FC_Net` is strongly inspired by the model found in https://www.kaggle.com/chriszou/titanic-with-pytorch-nn-solution

# %%
from models import FC_Net

# %% [markdown]
# ### Federated Learning Contribution Measure
# The following cells implement a federated learning setting, i.e. where a central server intitializes the model and then,
# for $r=1,...,$ `NUM_ROUNDS`:
#
# 1. The central server distributes the model to **all** the `NUM_CLIENTS` clients,
# 2. Each client trains the model on its own data (`EPOCHS` times using batch of size `BATCH_SIZE`),
# 3. Each client sends the trained model to the central server,
# 4. The central server evaluates the performance of the models on a test datasets (theoretically representing the distribution across users, i.e. the overall tasks),
# 5. The central server aggregates the models and update the contributions of each user.

# %% [markdown]
# ### Data loading and analysis

# %%
# loading
all_df, meta = load_into_df('income')

# plotting histograms
fig_all = all_df.hist(alpha=0.8, bins=10, figsize=(7, 7), 
                      layout=(5,3), sharey=True, xlabelsize=9, ylabelsize=9)


# style
plt.suptitle('Adult Income Dataset', y=0.92)
for x in fig_all.ravel():
    x.title.set_position([0.5, 0.76, 0, 0])
    x.title.set_size(10)
    x.title.set_size(10)
    x.set_yticks([0, 10000, 20000, 30000, 40000])
    x.set_yticklabels(['0', '1e4', '2e4', '3e4', '4e4'])

# saving
plt.savefig('./figures/adult_hist.png')

# statistics
print('Mean of each feature:\n{}\n'.format(all_df.mean()))
print('Number of features (with embeddings): {}'.format(meta['n_feat']))
# Out:
# Mean of each feature:
# age                    38.643585
# workclass               3.870439
# fnlwgt             189664.134597
# education              10.288420
# educational-num        10.078089
# marital-status          2.618750
# occupation              6.577700
# relationship            1.443287
# race                    3.668052
# gender                  0.668482
# capital-gain         1079.067626
# capital-loss           87.502314
# hours-per-week         40.422382
# native-country         36.749355
# income                  0.239282
# dtype: float64
#
# Number of features (with embeddings): 59

# %% [markdown]
# ### Parameters (to be specified)

# %%
# Number of clients
NUM_CLIENTS = 4

# Experiments

#SIZES = [0.4, 0.3, 0.2, 0.1]
#Y_ACC = [1., 1., 1., 1.]
#X_NOISE = [0., 0., 0., 0.]
#legends = SIZES

#SIZES = [0.25, 0.25, 0.25, 0.25]
#Y_ACC = [1., 0.98, 0.96, 0.94]
#X_NOISE = [0., 0., 0., 0.]
#legends = Y_ACC

SIZES = [0.25, 0.25, 0.25, 0.25]
Y_ACC = [1., 1., 1., 1.]
X_NOISE = [0., 0.1, 0.2, 0.3]
legends = X_NOISE

# Training parameters
NUM_ROUNDS = 100
EPOCHS = 1
LR = 1e-3
BATCH_SIZE = 32
F_TOT = 1
F_TEST = 0.3
THRESHOLD = 0.5
CRITERION = nn.BCELoss()
METRIC = 'loss_norm'
VERBOSE = True

# Model architecture
LIN_LAYERS_SIZES = [64, 16, 4]
OUTPUT_SIZE = 1

# Normalizing the datasets
all_df_norm = normalize(all_df, meta)

# Splitting the data into several datasets (train + test)
train_ds, test_ds = df_to_ds(all_df_norm, SIZES, meta, f_test=F_TEST, y_acc=Y_ACC, x_noise=X_NOISE)

# Creating the dataloaders
train_loaders = ds_to_dataloaders(train_ds, BATCH_SIZE)
test_loaders = ds_to_dataloaders(test_ds, 10*BATCH_SIZE, shuffle=False)
test_loader_s = ds_to_dataloaders(torch.utils.data.ConcatDataset(test_ds), 10*BATCH_SIZE, shuffle=False)
marg_test_loaders = [ds_to_dataloaders(torch.utils.data.ConcatDataset(test_ds[:i] + test_ds[i:]), 10*BATCH_SIZE, shuffle=False) for i in range(NUM_CLIENTS)]
# Out:
# Sizes:
# Full dataset: 48842
# Splitted datasets (total): 48840 (train: 34188, test: 14652)
# Per client: [12210, 12210, 12210, 12210]

# %% [markdown]
# ### Marginal losses and Shapley values

# %%
# initial model
initial_model = FC_Net(meta["emb_dims"], meta["n_cont"], LIN_LAYERS_SIZES, OUTPUT_SIZE)

# coalition models
coal_models = {}
coal_models_agg = {} 
coal_models_clients = {}

for coal in powerset(range(NUM_CLIENTS)):
    coal_models[coal] = FC_Net(meta["emb_dims"], meta["n_cont"], LIN_LAYERS_SIZES, OUTPUT_SIZE)
    coal_models[coal].load_state_dict(initial_model.state_dict())

    coal_models_agg[coal] = FC_Net(meta["emb_dims"], meta["n_cont"], LIN_LAYERS_SIZES, OUTPUT_SIZE)
    
    
    if coal != ():
        coal_models_clients[coal] = [FC_Net(meta["emb_dims"], meta["n_cont"], LIN_LAYERS_SIZES, OUTPUT_SIZE) for _ in coal]
    else:
        coal_models_clients[coal] = [FC_Net(meta["emb_dims"], meta["n_cont"], LIN_LAYERS_SIZES, OUTPUT_SIZE)]
        coal_models_agg[coal].load_state_dict(initial_model.state_dict())
        
# keys for the global model and the leave-one-out marginal models
global_coal = tuple(range(NUM_CLIENTS))
marg_coals = [tuple([i for i in range(NUM_CLIENTS) if i != j]) for j in range(NUM_CLIENTS)]

# performance measures
perf = initialize_perf((NUM_ROUNDS+1, 1)) # perf[0] contains the performance prior to learning
marg_perf = initialize_perf((NUM_ROUNDS, NUM_CLIENTS))
marg_perf_agg = initialize_perf((NUM_ROUNDS, NUM_CLIENTS))
perf_marg_ds = initialize_perf((NUM_ROUNDS, NUM_CLIENTS))
  
# contribution
SV = np.zeros((NUM_ROUNDS, NUM_CLIENTS))
SVa = np.zeros((NUM_ROUNDS, NUM_CLIENTS))
ML = np.zeros((NUM_ROUNDS, NUM_CLIENTS))
MLa = np.zeros((NUM_ROUNDS, NUM_CLIENTS))

# Untrained performance
fill_perf_history(evaluate_model(initial_model, test_loader_s, CRITERION, THRESHOLD), perf, (0, 0))
print('Prior performance ({}): {:.3f}'.format(METRIC, perf[METRIC][0, 0]))

# Iteration
for r in range(NUM_ROUNDS):
    t_start = time.time()
    if VERBOSE:
        print("------------------------------------\nRound {}:".format(r+1), end='')
    else:
        print("Round {}/{} (current {}: {:.3f})".format(r+1, NUM_ROUNDS, METRIC, perf[METRIC][r, 0]), end='\r')
        
    for coal in powerset(range(NUM_CLIENTS)):
        loss = 0
        for i, model in zip(coal, coal_models_clients[coal]):
            
            # step 1: Sending the models (emulating)
            model.load_state_dict(coal_models[coal].state_dict())
            
            # step 2: local training
            opt = optim.SGD(model.parameters(), lr=LR)
            loss += client_update(model, opt, CRITERION, train_loaders[i], epoch=EPOCHS)
      
    # step 4: aggregation
    for coal in powerset(range(NUM_CLIENTS)): 
        average_models(coal_models[coal], coal_models_clients[coal])
        if coal != ():
            average_models(coal_models_agg[coal], [coal_models_clients[global_coal][i] for i in coal])
    
    # global model performance on total test datasets
    fill_perf_history(evaluate_model(coal_models[global_coal], test_loader_s, CRITERION, THRESHOLD), perf,  (r + 1, 0))
    
    # step 5. Updating the contributions
    
    # SV and SVa
    #SV[r, :] = SV_FL(NUM_CLIENTS, coal_models, marg_test_loaders, METRIC, CRITERION, THRESHOLD)
    #SVa[r, :] = SV_FL(NUM_CLIENTS, coal_models_agg, marg_test_loaders, METRIC, CRITERION, THRESHOLD)
    
    SV[r, :] = SV_FL(NUM_CLIENTS, coal_models, test_loader_s, METRIC, CRITERION, THRESHOLD)
    SVa[r, :] = SV_FL(NUM_CLIENTS, coal_models_agg, test_loader_s, METRIC, CRITERION, THRESHOLD)    
    
    # ML and MLa
    for i in range(NUM_CLIENTS):
        # global model performance on marginal test datasets
        #fill_perf_history(evaluate_model(coal_models[global_coal], marg_test_loaders[i], CRITERION, THRESHOLD), perf_marg_ds, (r, i))
        
        # marginal models performance on marginal test datasets
        #fill_perf_history(evaluate_model(coal_models[marg_coals[i]], marg_test_loaders[i], CRITERION, THRESHOLD), marg_perf, (r, i))
        fill_perf_history(evaluate_model(coal_models[marg_coals[i]], test_loader_s, CRITERION, THRESHOLD), marg_perf, (r, i))
        
        # marginal models (during aggregation) performance on marginal test datasets
        #fill_perf_history(evaluate_model(coal_models_agg[marg_coals[i]], marg_test_loaders[i], CRITERION, THRESHOLD), marg_perf_agg, (r, i))
        fill_perf_history(evaluate_model(coal_models_agg[marg_coals[i]], test_loader_s, CRITERION, THRESHOLD), marg_perf_agg, (r, i))
    
    
    if METRIC == 'loss_norm':
        ML[r, :]= marg_perf[METRIC][r, :] - perf[METRIC][r, :]
        MLa[r, :] = marg_perf_agg[METRIC][r, :] - perf[METRIC][r, :] 
        #ML[r, :]= marg_perf[METRIC][r, :] - perf_marg_ds[METRIC][r, :]
        #MLa[r, :] = marg_perf_agg[METRIC][r, :] - perf_marg_ds[METRIC][r, :] 
    else:
        ML[r, :]= perf[METRIC][r, :] - marg_perf[METRIC][r, :]
        MLa[r, :] = perf[METRIC][r, :] - marg_perf_agg[METRIC][r, :] 
        #ML[r, :]= perf_marg_ds[METRIC][r, :] - marg_perf[METRIC][r, :]
        #MLa[r, :] = perf_marg_ds[METRIC][r, :] - marg_perf_agg[METRIC][r, :]
    
    
    t_round = time.time() - t_start
    
    if VERBOSE:
        print(" ({:.1f}s)".format(t_round))
        print("Performance:  {:.3f} ".format(perf[METRIC][r+1, 0]))
        print("SV:")
        print("  Total:      {}".format(SV[r, :]))
        print("  Cumulative: {}".format(SV.sum(0)))
        print("SVa:")
        print("  Total:      {}".format(SVa[r, :]))
        print("  Cumulative: {}".format(SVa.sum(0)))
        print("ML:")
        print("  Total:      {}".format(ML[r, :]))
        print("  Cumulative: {}".format(ML.sum(0)))
        print("MLa:")
        print("  Total:      {}".format(MLa[r, :]))
        print("  Cumulative: {}".format(MLa.sum(0)))

        
        
        
fill_perf_history(evaluate_model(coal_models[global_coal], test_loader_s, CRITERION, THRESHOLD), perf,  (-1, 0))
print("------------------------------------\nFinal performance ({}): {:.3f}".format(METRIC, perf[METRIC][-1, 0]))
# Out:
# Prior performance (loss_norm): 0.002
# ------------------------------------
# Round 1: (82.1s)
# Performance:  0.002
# SV:
#   Total:      [1.534e-05 2.246e-05 2.213e-05 1.916e-05]
#   Cumulative: [1.534e-05 2.246e-05 2.213e-05 1.916e-05]
# SVa:
#   Total:      [4.337e-05 5.572e-05 4.518e-05 4.214e-05]
#   Cumulative: [4.337e-05 5.572e-05 4.518e-05 4.214e-05]
# ML:
#   Total:      [-0. -0. -0. -0.]
#   Cumulative: [-0. -0. -0. -0.]
# MLa:
#   Total:      [-0. -0. -0. -0.]
#   Cumulative: [-0. -0. -0. -0.]
# ------------------------------------
# Round 2: (82.7s)
# Performance:  0.002
# SV:
#   Total:      [4.977e-05 5.653e-05 5.551e-05 4.211e-05]
#   Cumulative: [6.510e-05 7.899e-05 7.764e-05 6.127e-05]
# SVa:
#   Total:      [7.042e-05 7.799e-05 8.286e-05 8.000e-05]
#   Cumulative: [0. 0. 0. 0.]
# ML:
#   Total:      [-0. -0. -0. -0.]
#   Cumulative: [-0. -0. -0. -0.]
# MLa:
#   Total:      [-0. -0. -0. -0.]
#   Cumulative: [-0. -0. -0. -0.]
# ------------------------------------
# Round 3: (82.3s)
# Performance:  0.002
# SV:
#   Total:      [7.649e-05 7.474e-05 7.568e-05 7.011e-05]
#   Cumulative: [0. 0. 0. 0.]
# SVa:
#   Total:      [1.036e-04 1.030e-04 9.884e-05 9.899e-05]
#   Cumulative: [0. 0. 0. 0.]
# ML:
#   Total:      [-9.358e-05 -9.364e-05 -9.471e-05 -9.631e-05]
#   Cumulative: [-0. -0. -0. -0.]
# MLa:
#   Total:      [-9.176e-05 -9.191e-05 -9.435e-05 -9.427e-05]
#   Cumulative: [-0. -0. -0. -0.]
# ------------------------------------
# Round 4: (81.7s)
# Performance:  0.002
# SV:
#   Total:      [8.847e-05 8.942e-05 8.517e-05 8.136e-05]
#   Cumulative: [0. 0. 0. 0.]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0. 0. 0. 0.]
# ML:
#   Total:      [-4.621e-05 -4.551e-05 -5.058e-05 -4.961e-05]
#   Cumulative: [-0. -0. -0. -0.]
# MLa:
#   Total:      [-4.871e-05 -4.623e-05 -4.528e-05 -4.922e-05]
#   Cumulative: [-0. -0. -0. -0.]
# ------------------------------------
# Round 5: (81.4s)
# Performance:  0.001
# SV:
#   Total:      [9.796e-05 9.477e-05 9.284e-05 9.112e-05]
#   Cumulative: [0. 0. 0. 0.]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0. 0. 0. 0.]
# ML:
#   Total:      [-2.781e-05 -3.277e-05 -3.360e-05 -3.364e-05]
#   Cumulative: [-0.    -0.    -0.    -0.001]
# MLa:
#   Total:      [-3.373e-05 -3.061e-05 -3.116e-05 -3.356e-05]
#   Cumulative: [-0. -0. -0. -0.]
# ------------------------------------
# Round 6: (81.3s)
# Performance:  0.001
# SV:
#   Total:      [1.014e-04 1.035e-04 1.004e-04 9.368e-05]
#   Cumulative: [0. 0. 0. 0.]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.001 0.001 0.001 0.001]
# ML:
#   Total:      [-1.704e-05 -2.788e-05 -2.287e-05 -2.719e-05]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.225e-05 -2.299e-05 -1.920e-05 -2.427e-05]
#   Cumulative: [-0.001 -0.    -0.    -0.001]
# ------------------------------------
# Round 7: (81.9s)
# Performance:  0.001
# SV:
#   Total:      [1.068e-04 1.054e-04 1.046e-04 9.770e-05]
#   Cumulative: [0.001 0.001 0.001 0.   ]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.001 0.001 0.001 0.001]
# ML:
#   Total:      [-1.967e-05 -2.022e-05 -1.963e-05 -2.470e-05]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.790e-05 -1.501e-05 -1.407e-05 -1.527e-05]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 8: (80.9s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.001 0.001 0.001 0.001]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.001 0.001 0.001 0.001]
# ML:
#   Total:      [-2.045e-05 -2.425e-05 -2.227e-05 -2.868e-05]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.055e-05 -1.542e-05 -1.640e-05 -2.073e-05]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 9: (81.1s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.001 0.001 0.001 0.001]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.001 0.001 0.001 0.001]
# ML:
#   Total:      [-1.394e-05 -1.815e-05 -1.768e-05 -1.753e-05]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.615e-05 -1.195e-05 -1.572e-05 -1.570e-05]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 10: (80.5s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.001 0.001 0.001 0.001]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.001 0.001 0.001 0.001]
# ML:
#   Total:      [-1.542e-05 -1.507e-05 -1.497e-05 -1.572e-05]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.343e-05 -1.289e-05 -1.297e-05 -1.188e-05]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 11: (80.9s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.001 0.001 0.001 0.001]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.001 0.001 0.001 0.001]
# ML:
#   Total:      [-1.054e-05 -1.494e-05 -1.171e-05 -1.907e-05]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.660e-05 -1.540e-05 -1.613e-05 -1.573e-05]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 12: (81.1s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.001 0.001 0.001 0.001]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.001 0.001 0.001 0.001]
# ML:
#   Total:      [-5.726e-06 -7.608e-06 -7.735e-06 -1.077e-05]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.433e-05 -1.538e-05 -1.351e-05 -1.373e-05]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 13: (80.7s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.001 0.001 0.001 0.001]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.002 0.002 0.002 0.002]
# ML:
#   Total:      [-1.834e-06 -2.148e-06  1.358e-06 -2.263e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-7.467e-06 -5.865e-06 -5.190e-06 -9.837e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 14: (81.0s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.001 0.001 0.001 0.001]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.002 0.002 0.002 0.002]
# ML:
#   Total:      [-2.162e-06 -7.469e-06  9.362e-07 -3.298e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-3.987e-06 -5.798e-06 -6.608e-06 -6.420e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 15: (81.6s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.002 0.002 0.001 0.001]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.002 0.002 0.002 0.002]
# ML:
#   Total:      [-1.192e-06 -6.818e-06 -4.994e-06 -7.840e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-5.054e-06 -3.819e-06 -3.510e-06 -6.531e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 16: (80.4s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.002 0.002 0.002 0.002]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.002 0.002 0.002 0.002]
# ML:
#   Total:      [-4.653e-06 -8.561e-06 -6.371e-06 -1.251e-05]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-6.864e-06 -5.293e-06 -7.244e-06 -7.972e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 17: (80.9s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.002 0.002 0.002 0.002]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.002 0.002 0.002 0.002]
# ML:
#   Total:      [-6.008e-06 -6.800e-06 -1.750e-06 -1.124e-05]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.136e-05 -9.536e-06 -1.010e-05 -1.224e-05]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 18: (82.0s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.002 0.002 0.002 0.002]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.002 0.002 0.002 0.002]
# ML:
#   Total:      [-3.845e-07 -3.998e-06 -6.666e-07 -2.494e-07]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-3.518e-06 -2.598e-06 -2.010e-06 -3.284e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 19: (81.0s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.002 0.002 0.002 0.002]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.002 0.003 0.003 0.002]
# ML:
#   Total:      [-4.079e-06 -4.519e-06 -3.965e-06 -2.929e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-7.599e-06 -8.296e-06 -7.020e-06 -9.131e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 20: (80.8s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.002 0.002 0.002 0.002]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.003 0.003 0.003 0.003]
# ML:
#   Total:      [-1.971e-06 -2.039e-06 -2.937e-07 -3.810e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-3.790e-06 -3.671e-06 -2.392e-06 -3.579e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 21: (85.5s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.002 0.002 0.002 0.002]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.003 0.003 0.003 0.003]
# ML:
#   Total:      [-2.816e-06 -3.684e-06 -2.735e-06 -3.985e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-3.164e-06 -4.400e-06 -3.446e-06 -5.542e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 22: (81.6s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.002 0.002 0.002 0.002]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.003 0.003 0.003 0.003]
# ML:
#   Total:      [-3.138e-06 -2.572e-06 -3.928e-06 -5.571e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-6.717e-06 -5.777e-06 -4.405e-06 -8.314e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 23: (87.2s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.003 0.003 0.003 0.002]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.003 0.003 0.003 0.003]
# ML:
#   Total:      [-1.086e-06  1.310e-06  2.778e-06  2.175e-07]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.555e-07 -1.596e-06 -1.306e-06 -2.502e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 24: (104.6s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.003 0.003 0.003 0.003]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.003 0.003 0.003 0.003]
# ML:
#   Total:      [-1.415e-06 -4.958e-07  2.064e-06 -2.499e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-6.432e-06 -4.035e-06 -7.813e-07 -4.340e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 25: (99.5s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.003 0.003 0.003 0.003]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.003 0.004 0.004 0.003]
# ML:
#   Total:      [ 1.035e-06 -6.543e-07 -2.041e-07 -2.686e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-5.183e-06 -3.561e-06 -2.411e-06 -4.993e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 26: (94.8s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.003 0.003 0.003 0.003]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.004 0.004 0.004 0.004]
# ML:
#   Total:      [-9.405e-07  2.115e-06 -1.158e-06 -3.654e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-4.061e-06 -4.484e-06 -4.014e-06 -3.921e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 27: (95.4s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.003 0.003 0.003 0.003]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.004 0.004 0.004 0.004]
# ML:
#   Total:      [ 2.788e-07 -6.726e-07  7.722e-08 -4.970e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-3.458e-06 -4.208e-06 -1.835e-06 -3.221e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 28: (93.6s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.003 0.003 0.003 0.003]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.004 0.004 0.004 0.004]
# ML:
#   Total:      [-1.015e-06 -1.251e-06 -7.424e-07 -2.773e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.549e-06 -1.094e-06 -8.036e-09 -2.148e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 29: (95.4s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.003 0.003 0.003 0.003]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.004 0.004 0.004 0.004]
# ML:
#   Total:      [-2.627e-06 -9.757e-07  4.655e-07 -3.829e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-5.340e-06 -4.202e-06 -4.505e-06 -5.252e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 30: (93.6s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.004 0.004 0.004 0.003]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.004 0.004 0.004 0.004]
# ML:
#   Total:      [ 9.269e-07 -7.867e-08  9.598e-07 -5.015e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.088e-06 -2.274e-07 -1.071e-08 -3.584e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 31: (94.3s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.004 0.004 0.004 0.004]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.004 0.005 0.005 0.004]
# ML:
#   Total:      [ 1.111e-06 -3.228e-06 -1.698e-06 -5.066e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-5.101e-06 -3.644e-06 -5.446e-06 -6.151e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 32: (95.0s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.004 0.004 0.004 0.004]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.005 0.005 0.005 0.005]
# ML:
#   Total:      [ 9.303e-07 -2.380e-06 -2.190e-08 -2.876e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.509e-06 -2.120e-06 -8.921e-07 -2.710e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 33: (94.8s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.004 0.004 0.004 0.004]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.005 0.005 0.005 0.005]
# ML:
#   Total:      [ 9.358e-07 -2.068e-06 -3.594e-07 -6.275e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.597e-06 -3.502e-06 -3.939e-06 -4.995e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 34: (96.5s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.004 0.004 0.004 0.004]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.005 0.005 0.005 0.005]
# ML:
#   Total:      [ 4.679e-06 -1.098e-06  1.900e-06 -4.110e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-4.987e-07 -1.664e-07 -3.195e-07  7.813e-07]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 35: (99.0s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.004 0.004 0.004 0.004]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.005 0.005 0.005 0.005]
# ML:
#   Total:      [ 4.883e-07 -2.152e-06 -5.720e-07 -5.047e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.968e-06 -4.332e-06 -2.338e-06 -3.714e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 36: (112.2s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.004 0.004 0.004 0.004]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.005 0.005 0.005 0.005]
# ML:
#   Total:      [ 1.979e-07 -1.772e-06  1.922e-06 -4.695e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-3.081e-06 -2.391e-06 -6.232e-07 -2.821e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 37: (97.1s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.005 0.005 0.005 0.004]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.006 0.006 0.006 0.006]
# ML:
#   Total:      [ 4.790e-07 -9.619e-07  2.054e-06 -4.807e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.362e-06 -1.679e-06 -2.619e-06 -8.496e-07]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 38: (95.3s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.005 0.005 0.005 0.005]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.006 0.006 0.006 0.006]
# ML:
#   Total:      [ 4.147e-07 -4.056e-06  2.524e-06 -2.215e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.055e-06  1.738e-07  9.773e-08 -1.880e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 39: (108.5s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.005 0.005 0.005 0.005]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.006 0.006 0.006 0.006]
# ML:
#   Total:      [-3.181e-06 -1.140e-06 -2.501e-07 -4.305e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.796e-06 -2.585e-06 -1.000e-06 -3.373e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 40: (116.4s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.005 0.005 0.005 0.005]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.006 0.006 0.006 0.006]
# ML:
#   Total:      [-2.352e-06 -2.804e-06  2.150e-06 -2.880e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-4.288e-06 -3.737e-06 -2.576e-06 -4.227e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 41: (120.0s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.005 0.005 0.005 0.005]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.006 0.006 0.006 0.006]
# ML:
#   Total:      [-3.604e-07  8.881e-07  4.778e-07 -3.041e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.722e-06 -1.342e-06 -1.646e-06 -2.332e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 42: (89.9s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.005 0.005 0.005 0.005]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.006 0.006 0.007 0.006]
# ML:
#   Total:      [ 1.045e-06  1.163e-06 -4.988e-07 -4.054e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-3.767e-06 -3.553e-06 -2.441e-06 -3.619e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 43: (81.8s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.006 0.006 0.006 0.005]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.007 0.007 0.007 0.007]
# ML:
#   Total:      [ 3.510e-06  1.202e-06  4.164e-06 -1.422e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.461e-06 -1.511e-06  7.541e-08 -1.959e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 44: (81.8s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.006 0.006 0.006 0.005]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.007 0.007 0.007 0.007]
# ML:
#   Total:      [ 2.874e-06  9.857e-08  2.620e-06 -1.682e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.946e-06 -2.184e-06 -6.795e-07 -1.212e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 45: (84.9s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.006 0.006 0.006 0.006]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.007 0.007 0.007 0.007]
# ML:
#   Total:      [ 2.409e-06 -4.222e-07  3.865e-06 -2.710e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.479e-06 -2.240e-06 -1.985e-06 -2.902e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 46: (82.1s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.006 0.006 0.006 0.006]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.007 0.007 0.007 0.007]
# ML:
#   Total:      [ 2.619e-06  2.435e-07  4.143e-06 -3.067e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.396e-06 -9.674e-07 -8.902e-07 -2.312e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 47: (81.5s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.006 0.006 0.006 0.006]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.007 0.007 0.007 0.007]
# ML:
#   Total:      [ 1.435e-06  6.437e-07  3.028e-06 -2.517e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-7.581e-07 -8.616e-07  5.320e-07 -1.534e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 48: (81.9s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.006 0.006 0.006 0.006]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.007 0.008 0.008 0.007]
# ML:
#   Total:      [ 1.020e-06 -6.622e-07 -1.763e-08 -5.521e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.168e-06 -1.641e-06 -1.166e-06 -3.019e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 49: (81.1s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.006 0.006 0.006 0.006]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.008 0.008 0.008 0.008]
# ML:
#   Total:      [ 1.210e-06  2.863e-07  1.121e-06 -5.207e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.927e-06 -1.823e-06 -6.350e-07 -2.872e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 50: (81.1s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.007 0.007 0.007 0.006]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.008 0.008 0.008 0.008]
# ML:
#   Total:      [ 2.655e-06 -2.006e-07  6.506e-07 -4.755e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.690e-06 -1.331e-06 -1.691e-08 -4.163e-07]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 51: (80.6s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.007 0.007 0.007 0.006]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.008 0.008 0.008 0.008]
# ML:
#   Total:      [ 1.942e-06  3.432e-08  1.854e-06 -3.991e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.728e-06 -2.115e-06 -6.974e-07 -2.211e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 52: (81.2s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.007 0.007 0.007 0.007]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.008 0.008 0.008 0.008]
# ML:
#   Total:      [ 1.924e-06 -1.779e-06  7.552e-07 -4.290e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.502e-06 -1.107e-06  3.197e-07 -2.255e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 53: (81.2s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.007 0.007 0.007 0.007]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.008 0.008 0.009 0.008]
# ML:
#   Total:      [ 1.498e-06  8.134e-08  1.755e-06 -5.396e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.891e-06 -2.276e-06 -2.456e-06 -3.759e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 54: (86.1s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.007 0.007 0.007 0.007]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.009 0.009 0.009 0.009]
# ML:
#   Total:      [ 3.301e-06  2.722e-06  3.419e-06 -3.115e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.204e-06 -1.099e-06 -9.798e-07 -3.306e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 55: (84.2s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.007 0.007 0.007 0.007]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.009 0.009 0.009 0.009]
# ML:
#   Total:      [ 1.720e-06  2.135e-06  2.452e-06 -2.494e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.349e-06 -1.708e-08 -2.277e-07 -2.722e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 56: (81.8s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.008 0.008 0.008 0.007]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.009 0.009 0.009 0.009]
# ML:
#   Total:      [ 2.695e-06 -3.672e-07  1.399e-06 -3.570e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-5.589e-07 -6.646e-07  8.222e-07 -1.506e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 57: (81.6s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.008 0.008 0.008 0.007]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.009 0.009 0.009 0.009]
# ML:
#   Total:      [ 1.847e-06  2.487e-06  6.633e-07 -2.494e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.177e-06 -1.093e-06 -1.254e-06 -2.341e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 58: (82.0s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.008 0.008 0.008 0.007]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.009 0.009 0.009 0.009]
# ML:
#   Total:      [ 1.568e-06  2.276e-06  3.280e-06 -2.781e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.920e-07  1.267e-06  1.455e-06 -5.833e-07]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 59: (81.9s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.008 0.008 0.008 0.008]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.009 0.01  0.01  0.009]
# ML:
#   Total:      [ 8.395e-07  1.096e-06  1.531e-06 -3.826e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.477e-06 -1.847e-06 -1.792e-06 -2.427e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 60: (81.0s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.008 0.008 0.008 0.008]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.01 0.01 0.01 0.01]
# ML:
#   Total:      [ 2.685e-06 -1.661e-07  1.392e-06 -3.361e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.652e-07 -4.595e-08 -1.483e-07 -1.618e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 61: (80.9s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.008 0.008 0.008 0.008]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.01 0.01 0.01 0.01]
# ML:
#   Total:      [ 2.275e-06 -1.255e-07  1.063e-06 -6.263e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.983e-06 -1.350e-06 -7.402e-07 -2.702e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 62: (87.1s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.009 0.009 0.009 0.008]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.01 0.01 0.01 0.01]
# ML:
#   Total:      [ 1.908e-06  4.608e-07  7.243e-07 -3.670e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-5.796e-07 -4.308e-07  1.024e-06 -1.215e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 63: (84.7s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.009 0.009 0.009 0.008]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.01 0.01 0.01 0.01]
# ML:
#   Total:      [ 1.298e-06 -3.353e-07 -8.516e-07 -4.429e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.942e-06 -1.728e-06 -1.562e-06 -3.369e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 64: (81.6s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.009 0.009 0.009 0.008]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.01  0.011 0.011 0.01 ]
# ML:
#   Total:      [ 1.216e-06  1.725e-06  1.359e-07 -2.598e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.452e-06 -2.975e-06 -1.556e-06 -3.429e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 65: (81.7s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.009 0.009 0.009 0.009]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.011 0.011 0.011 0.011]
# ML:
#   Total:      [ 3.214e-06  1.605e-06  2.202e-06 -2.268e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [ 5.285e-07 -4.980e-08  1.129e-06 -3.037e-07]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 66: (81.3s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.009 0.009 0.009 0.009]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.011 0.011 0.011 0.011]
# ML:
#   Total:      [ 2.715e-06  4.996e-07  7.764e-07 -3.874e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.446e-06 -2.707e-06 -1.200e-06 -1.104e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 67: (82.2s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.009 0.009 0.009 0.009]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.011 0.011 0.011 0.011]
# ML:
#   Total:      [ 3.841e-06  2.507e-06 -5.763e-07 -4.135e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-7.933e-07 -1.384e-06 -2.982e-07 -2.283e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 68: (81.2s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.01  0.009 0.01  0.009]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.011 0.011 0.011 0.011]
# ML:
#   Total:      [ 3.071e-06  8.687e-07  1.151e-06 -4.755e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-4.330e-07 -9.518e-07  1.214e-06  2.432e-07]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 69: (81.3s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.01  0.01  0.01  0.009]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.011 0.011 0.011 0.011]
# ML:
#   Total:      [ 1.249e-06 -8.516e-07  1.704e-07 -6.019e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.951e-06 -1.402e-06 -1.930e-06 -2.232e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 70: (81.3s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.01  0.01  0.01  0.009]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.012 0.012 0.012 0.011]
# ML:
#   Total:      [ 7.465e-07 -2.821e-07  2.629e-06 -5.387e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.378e-06 -2.211e-06 -1.235e-06 -2.775e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 71: (81.7s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.01  0.01  0.01  0.009]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.012 0.012 0.012 0.012]
# ML:
#   Total:      [ 3.051e-06  3.499e-06  5.022e-06 -5.005e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.046e-06 -7.081e-07  1.013e-06 -1.075e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 72: (80.5s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.01 0.01 0.01 0.01]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.012 0.012 0.012 0.012]
# ML:
#   Total:      [ 3.395e-06  3.069e-06  2.932e-06 -5.986e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-3.665e-07 -1.066e-07 -2.311e-07 -8.311e-07]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 73: (80.1s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.01 0.01 0.01 0.01]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.012 0.012 0.012 0.012]
# ML:
#   Total:      [ 1.929e-06  1.040e-06  1.860e-06 -6.108e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-6.451e-07 -1.476e-06  2.301e-07 -1.862e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 74: (82.5s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.011 0.01  0.011 0.01 ]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.012 0.012 0.012 0.012]
# ML:
#   Total:      [ 4.984e-07  1.025e-06  1.589e-06 -6.680e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-5.147e-07 -4.335e-07  4.639e-07 -5.118e-07]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 75: (80.8s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.011 0.011 0.011 0.01 ]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.012 0.013 0.013 0.012]
# ML:
#   Total:      [ 3.718e-07  1.215e-06  7.977e-08 -5.643e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.293e-06 -2.956e-06 -1.340e-06 -2.785e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 76: (81.1s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.011 0.011 0.011 0.01 ]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.013 0.013 0.013 0.013]
# ML:
#   Total:      [ 2.744e-06  2.372e-06  1.902e-06 -3.619e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-9.861e-07 -1.293e-06  5.209e-08 -1.711e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 77: (93.8s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.011 0.011 0.011 0.01 ]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.013 0.013 0.013 0.013]
# ML:
#   Total:      [ 2.771e-06  1.485e-06  2.654e-06 -3.731e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [ 1.012e-07  3.278e-07  1.354e-06 -1.184e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 78: (84.1s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.011 0.011 0.011 0.01 ]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.013 0.013 0.013 0.013]
# ML:
#   Total:      [ 1.973e-06 -1.033e-07  3.693e-07 -3.819e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.472e-06 -1.042e-06 -2.041e-06 -3.475e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 79: (81.0s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.011 0.011 0.011 0.011]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.013 0.013 0.013 0.013]
# ML:
#   Total:      [ 3.992e-06  2.113e-06  1.551e-06 -2.841e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [1.544e-06 1.281e-06 1.095e-06 3.977e-07]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 80: (81.0s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.012 0.011 0.011 0.011]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.013 0.014 0.014 0.013]
# ML:
#   Total:      [ 1.390e-06 -6.745e-07  2.520e-07 -5.278e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.810e-06 -2.106e-06 -1.838e-06 -2.598e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 81: (81.5s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.012 0.012 0.012 0.011]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.014 0.014 0.014 0.014]
# ML:
#   Total:      [ 1.902e-06  2.082e-06  1.905e-06 -4.640e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.390e-06 -3.002e-07  3.235e-07 -1.847e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 82: (90.7s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.012 0.012 0.012 0.011]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.014 0.014 0.014 0.014]
# ML:
#   Total:      [ 2.301e-06  2.042e-06  1.732e-06 -6.212e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-6.897e-07 -3.666e-07  6.482e-07 -1.884e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 83: (86.6s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.012 0.012 0.012 0.011]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.014 0.014 0.014 0.014]
# ML:
#   Total:      [ 2.396e-06  1.138e-07  1.127e-06 -5.782e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.719e-06 -2.263e-06 -1.435e-06 -1.636e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 84: (82.3s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.012 0.012 0.012 0.011]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.014 0.014 0.014 0.014]
# ML:
#   Total:      [ 3.657e-06  2.446e-06  1.406e-06 -5.178e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-4.181e-07 -7.337e-08  1.348e-07 -1.144e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 85: (81.8s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.012 0.012 0.012 0.012]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.014 0.014 0.015 0.014]
# ML:
#   Total:      [ 4.126e-06  1.466e-06  2.663e-06 -4.490e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.185e-06 -4.764e-07  8.011e-07 -1.082e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 86: (81.7s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.013 0.012 0.012 0.012]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.015 0.015 0.015 0.014]
# ML:
#   Total:      [ 3.322e-06  6.688e-07  2.433e-06 -4.604e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-5.260e-07 -1.242e-06 -7.910e-07 -2.178e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 87: (81.3s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.013 0.013 0.013 0.012]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.015 0.015 0.015 0.015]
# ML:
#   Total:      [ 4.641e-06  2.431e-07  2.775e-06 -4.139e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-8.779e-07 -7.180e-07 -3.999e-07 -1.087e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 88: (81.2s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.013 0.013 0.013 0.012]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.015 0.015 0.015 0.015]
# ML:
#   Total:      [ 4.246e-06  8.030e-07  1.184e-06 -3.973e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-6.848e-07 -9.796e-07 -3.321e-07 -1.245e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 89: (80.6s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.013 0.013 0.013 0.012]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.015 0.015 0.015 0.015]
# ML:
#   Total:      [ 4.621e-06  9.651e-07  1.849e-06 -3.597e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-5.993e-07 -4.326e-07  8.866e-07 -6.718e-07]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 90: (80.6s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.013 0.013 0.013 0.012]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.015 0.015 0.016 0.015]
# ML:
#   Total:      [ 2.759e-06  1.175e-06  2.727e-06 -4.577e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [ 1.951e-07 -5.756e-07  8.163e-07 -1.956e-07]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 91: (82.2s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.013 0.013 0.013 0.013]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.016 0.016 0.016 0.015]
# ML:
#   Total:      [ 3.005e-06 -3.915e-07  8.675e-07 -5.692e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-5.532e-07 -1.681e-06 -1.410e-09 -1.570e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 92: (81.0s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.014 0.013 0.013 0.013]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.016 0.016 0.016 0.016]
# ML:
#   Total:      [ 2.618e-06  9.658e-07  5.685e-07 -5.592e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-2.289e-07 -5.297e-07  1.844e-07 -1.614e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 93: (85.2s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.014 0.014 0.014 0.013]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.016 0.016 0.016 0.016]
# ML:
#   Total:      [ 2.013e-06  2.127e-06 -1.309e-07 -4.407e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-7.764e-07 -1.328e-06 -1.888e-08 -1.245e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 94: (92.1s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.014 0.014 0.014 0.013]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.016 0.016 0.016 0.016]
# ML:
#   Total:      [ 3.490e-06  1.427e-06  9.422e-07 -4.376e-06]
#   Cumulative: [-0.    -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-3.898e-07 -6.641e-07  3.845e-07 -4.484e-07]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 95: (81.0s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.014 0.014 0.014 0.013]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.016 0.016 0.016 0.016]
# ML:
#   Total:      [ 3.288e-06  5.716e-07  2.955e-07 -5.714e-06]
#   Cumulative: [-0.    -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-5.187e-07 -5.438e-07  1.113e-07 -1.484e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 96: (81.4s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.014 0.014 0.014 0.013]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.016 0.017 0.017 0.016]
# ML:
#   Total:      [ 3.289e-06  3.449e-07  6.170e-07 -5.411e-06]
#   Cumulative: [-0.    -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-9.475e-07 -1.060e-06  7.085e-07 -1.052e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 97: (81.5s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.014 0.014 0.014 0.013]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.017 0.017 0.017 0.017]
# ML:
#   Total:      [ 2.775e-06 -7.855e-08  2.530e-06 -3.105e-06]
#   Cumulative: [-0.    -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.420e-06 -1.775e-06 -1.840e-06 -1.721e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 98: (81.0s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.015 0.014 0.014 0.014]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.017 0.017 0.017 0.017]
# ML:
#   Total:      [ 4.510e-06  1.032e-06  1.863e-06 -4.202e-06]
#   Cumulative: [-0.    -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-6.928e-07 -1.502e-06 -1.025e-06 -1.093e-06]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 99: (86.4s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.015 0.015 0.015 0.014]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.017 0.017 0.017 0.017]
# ML:
#   Total:      [ 5.622e-06  3.726e-07  2.608e-06 -3.120e-06]
#   Cumulative: [-0.    -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-6.833e-07 -3.630e-07  2.148e-07 -6.611e-07]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Round 100: (81.4s)
# Performance:  0.001
# SV:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.015 0.015 0.015 0.014]
# SVa:
#   Total:      [0. 0. 0. 0.]
#   Cumulative: [0.017 0.017 0.017 0.017]
# ML:
#   Total:      [ 5.163e-06 -4.579e-07  1.968e-06 -3.228e-06]
#   Cumulative: [-0.    -0.001 -0.001 -0.001]
# MLa:
#   Total:      [-1.329e-07 -7.334e-07 -5.821e-08 -4.053e-07]
#   Cumulative: [-0.001 -0.001 -0.001 -0.001]
# ------------------------------------
# Final performance (loss_norm): 0.001

# %% [markdown]
# ### Training history vizualization

# %%
plotmetrics = ['loss_norm', 'accuracy', 'f1']

# Model performance
fig_perf = perfplots(perf, suptitle='Model Performance (server)', metrics=plotmetrics)

# %%
# ROC curve
fig_ROC = ROC(coal_models[global_coal], test_loader_s)
# Out:
# Building the ROC plot (101/101 evaluations)

# %%
# Contribution plot
modes = ['round_maxmax', 'round_minmax', 'cum', 'minmax', 'maxmax']
modes = ['round', 'cum']
fig_SV = contriplot(SV, legends=legends, normalize=True, modes=modes, suptitle="Shapley Values")
fig_SVa = contriplot(SVa, legends=legends, normalize=True, modes=modes, suptitle="Shapley Values at Aggregation")
fig_ML = contriplot(ML, legends=legends, normalize=True, modes=modes, suptitle="Marginal Losses")
fig_MLa = contriplot(MLa, legends=legends, normalize=True, modes=modes, suptitle="Marginal Losses at Aggregation")

# %% [markdown]
# ### Saving

# %%
from datetime import datetime
import dill
import os

### Saving the relevant objects
now = datetime.now()
time = now.strftime('%d_%m_%Hh%M')
subdir = "FL_n{}_r{}_{}/".format(NUM_CLIENTS, NUM_ROUNDS, time)

fig_dir = './saves/' + subdir + 'figures/'
save_dir = './saves/' + subdir

if not os.path.exists(fig_dir):
    os.makedirs(fig_dir)
    
print(save_dir)
# Out:
# ./saves/FL_n4_r100_04_06_17h07/

# %% [markdown]
# Figures

# %%
fig_perf.savefig(fig_dir + 'perf.png')
fig_ROC.savefig(fig_dir + 'ROC.png')
fig_SV.savefig(fig_dir + 'SV.png')
fig_SVa.savefig(fig_dir + 'SVa.png')
fig_ML.savefig(fig_dir + 'ML.png')
fig_MLa.savefig(fig_dir + 'MLa.png')

# %% [markdown]
# Variables

# %%
dill.dump_session(save_dir + 'variables.pckl')

# %% [markdown]
# ### Loading

# %%
import dill
directory = './saves/FL_n4_r100_25_05_23h42/'
dill.load_session(directory + 'variables.pckl')
